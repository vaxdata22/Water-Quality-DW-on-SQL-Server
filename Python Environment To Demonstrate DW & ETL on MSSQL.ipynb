# %% [markdown]
# # Python Environment To Demonstrate DW & ETL on MSSQL

# %% [markdown]
# #### Important Note: Kindly run the cells one by one. Some cells give output, some don't.

# %%
### SET UP THE PYTHON QUERYING ENVIRONMENT ###

## Run this cell only once. Expect no output ##

# !pip install pyodbc
import pyodbc
import pandas as pd
import warnings as wn
wn.filterwarnings('ignore')
conn = pyodbc.connect(r'Driver=SQL Server Native Client 11.0;Server=localhost;Database=water_quality;Trusted_Connection=yes;')
cursor = conn.cursor()

# By running this cell, connection is made from this Python environment to a SQL Server 2019 database already on the local machine.
# Out:
# Requirement already satisfied: pyodbc in c:\users\donatus enebuse\anaconda3\lib\site-packages (4.0.32)

# %% [markdown]
# ### Extract Phase

# %%
### COMBINE ALL 17 RAW IMPORTED TABLES INTO ONE BIG STAGING TABLE ###

## Run this cell only once. Expect no output ##

cursor.execute("""

USE water_quality;

DROP TABLE IF EXISTS dw_water_quality;

SELECT * INTO dw_water_quality FROM _2000;

INSERT INTO dw_water_quality
    SELECT * FROM _2001
        UNION
    SELECT * FROM _2002
        UNION
    SELECT * FROM _2003
        UNION
    SELECT * FROM _2004
        UNION
    SELECT * FROM _2005
        UNION
    SELECT * FROM _2006
        UNION
    SELECT * FROM _2007
        UNION
    SELECT * FROM _2008
        UNION
    SELECT * FROM _2009
        UNION
    SELECT * FROM _2010
        UNION
    SELECT * FROM _2011
        UNION
    SELECT * FROM _2012
        UNION
    SELECT * FROM _2013
        UNION
    SELECT * FROM _2014
        UNION
    SELECT * FROM _2015
        UNION
    SELECT * FROM _2016;
        
            """)


conn.commit()

# %%
### EXAMINE THE STAGING TABLE THAT HAS BEEN PREPARED ###

## You can run this cell more than once, but don't re-run this cell after the TRANSFORM PHASE. Expect a dataframe ##

query = """

SELECT * FROM dw_water_quality;

        """

df = pd.read_sql_query(query, conn)
df

# 2348 records. 19 fields.
# Out:
#       ID1      ID                                                @id  \
# 0       1     1.0  http://environment.data.gov.uk/water-quality/d...
# 1       2     9.0  http://environment.data.gov.uk/water-quality/d...
# 2       3    17.0  http://environment.data.gov.uk/water-quality/d...
# 3       4    25.0  http://environment.data.gov.uk/water-quality/d...
# 4       5    33.0  http://environment.data.gov.uk/water-quality/d...
# ...   ...     ...                                                ...
# 2343  255  1352.0  http://environment.data.gov.uk/water-quality/d...
# 2344  255  2541.0  http://environment.data.gov.uk/water-quality/d...
# 2345  256  1353.0  http://environment.data.gov.uk/water-quality/d...
# 2346  257  1354.0  http://environment.data.gov.uk/water-quality/d...
# 2347  258  1355.0  http://environment.data.gov.uk/water-quality/d...
#
#                                     samplesamplingPoint  \
# 0     http://environment.data.gov.uk/water-quality/i...
# 1     http://environment.data.gov.uk/water-quality/i...
# 2     http://environment.data.gov.uk/water-quality/i...
# 3     http://environment.data.gov.uk/water-quality/i...
# 4     http://environment.data.gov.uk/water-quality/i...
# ...                                                 ...
# 2343  http://environment.data.gov.uk/water-quality/i...
# 2344  http://environment.data.gov.uk/water-quality/i...
# 2345  http://environment.data.gov.uk/water-quality/i...
# 2346  http://environment.data.gov.uk/water-quality/i...
# 2347  http://environment.data.gov.uk/water-quality/i...
#
#      samplesamplingPointnotation               samplesamplingPointlabel  \
# 0                      AN-011396     BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 1                      AN-011396     BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 2                      AN-011489        RED HOUSE NURSING HOME SYRESHAM
# 3                       AN-01M04             R.OUSE A422 RD.BR.BRACKLEY
# 4                       AN-01M04             R.OUSE A422 RD.BR.BRACKLEY
# ...                          ...                                    ...
# 2343                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 2344                 NE-43100100                REDE AT COTTONSHOPEFOOT
# 2345                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 2346                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 2347                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
#
#      samplesampleDateTime determinandlabel       determinanddefinition  \
# 0     2000-01-04T14:10:00       Ammonia(N)    Ammoniacal Nitrogen as N
# 1     2000-11-15T14:50:00     Sld Sus@105C  Solids, Suspended at 105 C
# 2     2000-07-17T10:15:00     Sld Sus@105C  Solids, Suspended at 105 C
# 3     2000-01-24T10:55:00     Iron - as Fe                        Iron
# 4     2000-01-24T10:55:00     Sld Sus@105C  Solids, Suspended at 105 C
# ...                   ...              ...                         ...
# 2343  2012-05-21T11:31:00     Sld Sus@105C  Solids, Suspended at 105 C
# 2344  2015-11-30T10:59:00      Ca Filtered          Calcium, Dissolved
# 2345  2012-06-14T14:29:00     Sld Sus@105C  Solids, Suspended at 105 C
# 2346  2012-06-14T14:29:00        Nitrate-N                Nitrate as N
# 2347  2012-06-14T14:29:00        Nitrite-N                Nitrite as N
#
#       determinandnotation resultQualifiernotation    result  \
# 0                   111.0                    None   10.4000
# 1                   135.0                    None   14.4000
# 2                   135.0                    None   65.3000
# 3                  6051.0                    None  160.0000
# 4                   135.0                    None    4.0000
# ...                   ...                     ...       ...
# 2343                135.0                    None    3.7800
# 2344                239.0                    None   10.2000
# 2345                135.0                    None    8.6700
# 2346                117.0                    None    6.0400
# 2347                118.0                    None    0.0378
#
#      codedResultInterpretationinterpretation determinandunitlabel  \
# 0                                       None                 mg/l
# 1                                       None                 mg/l
# 2                                       None                 mg/l
# 3                                       None                 ug/l
# 4                                       None                 mg/l
# ...                                      ...                  ...
# 2343                                    None                 mg/l
# 2344                                    None                 mg/l
# 2345                                    None                 mg/l
# 2346                                    None                 mg/l
# 2347                                    None                 mg/l
#
#      samplesampledMaterialTypelabel  sampleisComplianceSample  \
# 0             FINAL SEWAGE EFFLUENT                      True
# 1             FINAL SEWAGE EFFLUENT                      True
# 2             FINAL SEWAGE EFFLUENT                     False
# 3     RIVER / RUNNING SURFACE WATER                     False
# 4     RIVER / RUNNING SURFACE WATER                     False
# ...                             ...                       ...
# 2343  RIVER / RUNNING SURFACE WATER                     False
# 2344  RIVER / RUNNING SURFACE WATER                     False
# 2345  RIVER / RUNNING SURFACE WATER                     False
# 2346  RIVER / RUNNING SURFACE WATER                     False
# 2347  RIVER / RUNNING SURFACE WATER                     False
#
#                                      samplepurposelabel  \
# 0                             COMPLIANCE AUDIT (PERMIT)
# 1                             COMPLIANCE AUDIT (PERMIT)
# 2     UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
# 3     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# ...                                                 ...
# 2343     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2344  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 2345     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2346     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2347     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
#
#       samplesamplingPointeasting  samplesamplingPointnorthing
# 0                       467020.0                     233400.0
# 1                       467020.0                     233400.0
# 2                       462060.0                     240890.0
# 3                       459427.0                     236819.0
# 4                       459427.0                     236819.0
# ...                          ...                          ...
# 2343                    470377.0                     228850.0
# 2344                    377820.0                     601280.0
# 2345                    470377.0                     228850.0
# 2346                    470377.0                     228850.0
# 2347                    470377.0                     228850.0
#
# [2348 rows x 19 columns]

# %% [markdown]
# ### Transform Phase

# %% [markdown]
# ##### Examine the ID1 column

# %%
### CHECK THE ID1 COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT ID1 
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 258 distinct values! This column will not be needed in the load phase.
# Out:
#      ID1
# 0     23
# 1    238
# 2     46
# 3    215
# 4     69
# ..   ...
# 253   51
# 254  151
# 255  194
# 256  200
# 257  100
#
# [258 rows x 1 columns]

# %%
### CHECK THE ID1 COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE ID1 IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values. This column will still not be needed in the load phase.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the ID column

# %%
### CHECK THE ID COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT ID 
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 1048 distinct values! This column will not be needed in the load phase.
# Out:
#           ID
# 0      713.0
# 1     1981.0
# 2     1211.0
# 3     1384.0
# 4      953.0
# ...      ...
# 1043  1155.0
# 1044   791.0
# 1045   473.0
# 1046    39.0
# 1047   925.0
#
# [1048 rows x 1 columns]

# %%
### CHECK THE ID COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE ID IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values. This column will still not be needed in the load phase.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the @id column

# %%
### CHECK THE @id COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT [@id] 
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 2348 distinct values. This column could serve as a unique key column.
# Out:
#                                                     @id
# 0     http://environment.data.gov.uk/water-quality/d...
# 1     http://environment.data.gov.uk/water-quality/d...
# 2     http://environment.data.gov.uk/water-quality/d...
# 3     http://environment.data.gov.uk/water-quality/d...
# 4     http://environment.data.gov.uk/water-quality/d...
# ...                                                 ...
# 2343  http://environment.data.gov.uk/water-quality/d...
# 2344  http://environment.data.gov.uk/water-quality/d...
# 2345  http://environment.data.gov.uk/water-quality/d...
# 2346  http://environment.data.gov.uk/water-quality/d...
# 2347  http://environment.data.gov.uk/water-quality/d...
#
# [2348 rows x 1 columns]

# %%
### CHECK THE @id COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE [@id] IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesamplingPoint column

# %%
### CHECK THE ID_ COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesamplingPoint 
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 81 distinct values.
# Out:
#                                   samplesamplingPoint
# 0   http://environment.data.gov.uk/water-quality/i...
# 1   http://environment.data.gov.uk/water-quality/i...
# 2   http://environment.data.gov.uk/water-quality/i...
# 3   http://environment.data.gov.uk/water-quality/i...
# 4   http://environment.data.gov.uk/water-quality/i...
# ..                                                ...
# 76  http://environment.data.gov.uk/water-quality/i...
# 77  http://environment.data.gov.uk/water-quality/i...
# 78  http://environment.data.gov.uk/water-quality/i...
# 79  http://environment.data.gov.uk/water-quality/i...
# 80  http://environment.data.gov.uk/water-quality/i...
#
# [81 rows x 1 columns]

# %%
### CHECK THE samplesamplingPoint COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesamplingPoint IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesamplingPointnotation column

# %%
### CHECK THE samplesamplingPointnotation COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesamplingPointnotation 
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 81 distinct values.
# Out:
#    samplesamplingPointnotation
# 0                     AN-04959
# 1                     AN-04M15
# 2                  MD-36791360
# 3                     AN-02M25
# 4                     AN-01558
# ..                         ...
# 76                    AN-04M13
# 77                    AN-02M10
# 78                 MD-03332190
# 79                   AN-011638
# 80                    AN-04M17
#
# [81 rows x 1 columns]

# %%
### CHECK THE samplesamplingPointnotation COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesamplingPointnotation IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesamplingPointlabel column

# %%
### CHECK THE samplesamplingPointlabel COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesamplingPointlabel
    FROM dw_water_quality;
    
    """

df = pd.read_sql_query(query, conn)
df

# 81 distinct locations.
# Out:
#                    samplesamplingPointlabel
# 0              R.TOVE A508 RD.BR.STOKE PARK
# 1               TRIB.OUZEL BK.D/S BLUEWATER
# 2                 HELMDON BK.HELMDON RD.BR.
# 3                   PRESTON BROOK WINDCROSS
# 4                CLUBHOUSE GT.LINFORD LAKES
# ..                                      ...
# 76          STEANE PARK THE MANOR HOUSE STW
# 77                             FALDINGWORTH
# 78    BLAKESLEY BK.TRIB.TOVE KINGTHORN MILL
# 79                       SANDHOUSE BACKWASH
# 80  APOLLO OFFICE UNITS RADCLIVE RD GAWCOTT
#
# [81 rows x 1 columns]

# %%
### CHECK THE samplesamplingPointlabel COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesamplingPointlabel IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null values.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesampleDateTime column

# %%
### CHECK THE samplesampleDateTime COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesampleDateTime
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 1077 distinct timestamps.
# Out:
#      samplesampleDateTime
# 0     2000-01-04T14:10:00
# 1     2000-01-10T13:25:00
# 2     2000-01-24T09:40:00
# 3     2000-01-24T10:00:00
# 4     2000-01-24T10:25:00
# ...                   ...
# 1072  2016-12-05T13:58:00
# 1073  2016-12-05T14:23:00
# 1074  2016-12-05T15:05:00
# 1075  2016-12-07T13:00:00
# 1076  2016-12-16T10:32:00
#
# [1077 rows x 1 columns]

# %%
### CHECK THE samplesampleDateTime COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesampleDateTime IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the determinandlabel AND determinanddefinition AND determinandnotation columns

# %%
### CHECK THE determinandlabel COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT determinandlabel
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 173 distinct 'sensor' types.
# Out:
#     determinandlabel
# 0          1,1,1-TCA
# 1          1,2,4-TCB
# 2       1122TetClEth
# 3             12-DCA
# 4       2,3,5,6-Tetr
# ..               ...
# 168     WethPresPrec
# 169     WethPresTemp
# 170     Weth-Visibty
# 171     Zinc - as Zn
# 172     Zn- Filtered
#
# [173 rows x 1 columns]

# %%
### CHECK THE determinanddefinition COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT determinanddefinition
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 172 distinct values.
# Out:
#                  determinanddefinition
# 0                1,1,1-Trichloroethane
# 1            1,1,2,2-Tetrachloroethane
# 2               1,2,4-Trichlorobenzene
# 3                   1,2-Dichloroethane
# 4    1,2-Dimethylbenzene :- {o-Xylene}
# ..                                 ...
# 167            Weather : Precipitation
# 168              Weather : Temperature
# 169               Weather : Visibility
# 170                               Zinc
# 171                    Zinc, Dissolved
#
# [172 rows x 1 columns]

# %%
### CHECK THE determinandnotation COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT determinandnotation
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 173 distinct values.
# Out:
#      determinandnotation
# 0                 3878.0
# 1                 3410.0
# 2                 6569.0
# 3                   81.0
# 4                 6841.0
# ..                   ...
# 168               9447.0
# 169               3781.0
# 170                746.0
# 171               6619.0
# 172               6458.0
#
# [173 rows x 1 columns]

# %%
### CHECK THE determinandlabel AND determinanddefinition AND determinandnotation COLUMNS FOR NULL VALUES

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE determinandlabel IS NULL
    OR determinanddefinition IS NULL
    OR determinandnotation IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %%
### CHECK THE determinandlabel COLUMN FOR OUTLIERS ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT determinandlabel, COUNT(determinandlabel) cnt
    FROM dw_water_quality
GROUP BY determinandlabel 
ORDER BY cnt;

        """

df = pd.read_sql_query(query, conn)
df

# Up to 95 'sensors' out of 163 appear less than three times. Click to the left of the dataframe to scroll.
# This observation will be ignored for this project.
# Out:
#     determinandlabel  cnt
# 0          1,1,1-TCA    1
# 1          1,2,4-TCB    1
# 2       1122TetClEth    1
# 3       2,3,5,6-Tetr    1
# 4        2,3-Xylenol    1
# ..               ...  ...
# 168       N Oxidised  118
# 169     Orthophospht  126
# 170      O Diss %sat  131
# 171               pH  134
# 172       Ammonia(N)  157
#
# [173 rows x 2 columns]

# %% [markdown]
# ##### Examine the resultQualifiernotation column

# %%
### CHECK THE resultQualifiernotation COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT resultQualifiernotation 
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 2 distinct values. Null and "<". This column will not be used in the load phase since it contains null values.
# Out:
#   resultQualifiernotation
# 0                    None
# 1                       <

# %%
### CHECK THE resultQualifiernotation COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE resultQualifiernotation IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# 1845 null values! This column will not be used in the load phase since it contains a lot of null values.
# Out:
#       ID1      ID                                                @id  \
# 0       1     1.0  http://environment.data.gov.uk/water-quality/d...
# 1       2     9.0  http://environment.data.gov.uk/water-quality/d...
# 2       3    17.0  http://environment.data.gov.uk/water-quality/d...
# 3       4    25.0  http://environment.data.gov.uk/water-quality/d...
# 4       5    33.0  http://environment.data.gov.uk/water-quality/d...
# ...   ...     ...                                                ...
# 1840  255  1352.0  http://environment.data.gov.uk/water-quality/d...
# 1841  255  2541.0  http://environment.data.gov.uk/water-quality/d...
# 1842  256  1353.0  http://environment.data.gov.uk/water-quality/d...
# 1843  257  1354.0  http://environment.data.gov.uk/water-quality/d...
# 1844  258  1355.0  http://environment.data.gov.uk/water-quality/d...
#
#                                     samplesamplingPoint  \
# 0     http://environment.data.gov.uk/water-quality/i...
# 1     http://environment.data.gov.uk/water-quality/i...
# 2     http://environment.data.gov.uk/water-quality/i...
# 3     http://environment.data.gov.uk/water-quality/i...
# 4     http://environment.data.gov.uk/water-quality/i...
# ...                                                 ...
# 1840  http://environment.data.gov.uk/water-quality/i...
# 1841  http://environment.data.gov.uk/water-quality/i...
# 1842  http://environment.data.gov.uk/water-quality/i...
# 1843  http://environment.data.gov.uk/water-quality/i...
# 1844  http://environment.data.gov.uk/water-quality/i...
#
#      samplesamplingPointnotation               samplesamplingPointlabel  \
# 0                      AN-011396     BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 1                      AN-011396     BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 2                      AN-011489        RED HOUSE NURSING HOME SYRESHAM
# 3                       AN-01M04             R.OUSE A422 RD.BR.BRACKLEY
# 4                       AN-01M04             R.OUSE A422 RD.BR.BRACKLEY
# ...                          ...                                    ...
# 1840                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 1841                 NE-43100100                REDE AT COTTONSHOPEFOOT
# 1842                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 1843                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 1844                    AN-02M10  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
#
#      samplesampleDateTime determinandlabel       determinanddefinition  \
# 0     2000-01-04T14:10:00       Ammonia(N)    Ammoniacal Nitrogen as N
# 1     2000-11-15T14:50:00     Sld Sus@105C  Solids, Suspended at 105 C
# 2     2000-07-17T10:15:00     Sld Sus@105C  Solids, Suspended at 105 C
# 3     2000-01-24T10:55:00     Iron - as Fe                        Iron
# 4     2000-01-24T10:55:00     Sld Sus@105C  Solids, Suspended at 105 C
# ...                   ...              ...                         ...
# 1840  2012-05-21T11:31:00     Sld Sus@105C  Solids, Suspended at 105 C
# 1841  2015-11-30T10:59:00      Ca Filtered          Calcium, Dissolved
# 1842  2012-06-14T14:29:00     Sld Sus@105C  Solids, Suspended at 105 C
# 1843  2012-06-14T14:29:00        Nitrate-N                Nitrate as N
# 1844  2012-06-14T14:29:00        Nitrite-N                Nitrite as N
#
#       determinandnotation resultQualifiernotation    result  \
# 0                   111.0                    None   10.4000
# 1                   135.0                    None   14.4000
# 2                   135.0                    None   65.3000
# 3                  6051.0                    None  160.0000
# 4                   135.0                    None    4.0000
# ...                   ...                     ...       ...
# 1840                135.0                    None    3.7800
# 1841                239.0                    None   10.2000
# 1842                135.0                    None    8.6700
# 1843                117.0                    None    6.0400
# 1844                118.0                    None    0.0378
#
#      codedResultInterpretationinterpretation determinandunitlabel  \
# 0                                       None                 mg/l
# 1                                       None                 mg/l
# 2                                       None                 mg/l
# 3                                       None                 ug/l
# 4                                       None                 mg/l
# ...                                      ...                  ...
# 1840                                    None                 mg/l
# 1841                                    None                 mg/l
# 1842                                    None                 mg/l
# 1843                                    None                 mg/l
# 1844                                    None                 mg/l
#
#      samplesampledMaterialTypelabel  sampleisComplianceSample  \
# 0             FINAL SEWAGE EFFLUENT                      True
# 1             FINAL SEWAGE EFFLUENT                      True
# 2             FINAL SEWAGE EFFLUENT                     False
# 3     RIVER / RUNNING SURFACE WATER                     False
# 4     RIVER / RUNNING SURFACE WATER                     False
# ...                             ...                       ...
# 1840  RIVER / RUNNING SURFACE WATER                     False
# 1841  RIVER / RUNNING SURFACE WATER                     False
# 1842  RIVER / RUNNING SURFACE WATER                     False
# 1843  RIVER / RUNNING SURFACE WATER                     False
# 1844  RIVER / RUNNING SURFACE WATER                     False
#
#                                      samplepurposelabel  \
# 0                             COMPLIANCE AUDIT (PERMIT)
# 1                             COMPLIANCE AUDIT (PERMIT)
# 2     UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
# 3     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# ...                                                 ...
# 1840     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 1841  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 1842     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 1843     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 1844     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
#
#       samplesamplingPointeasting  samplesamplingPointnorthing
# 0                       467020.0                     233400.0
# 1                       467020.0                     233400.0
# 2                       462060.0                     240890.0
# 3                       459427.0                     236819.0
# 4                       459427.0                     236819.0
# ...                          ...                          ...
# 1840                    470377.0                     228850.0
# 1841                    377820.0                     601280.0
# 1842                    470377.0                     228850.0
# 1843                    470377.0                     228850.0
# 1844                    470377.0                     228850.0
#
# [1845 rows x 19 columns]

# %% [markdown]
# ##### Examine the result column

# %%
### CHECK THE result COLUMN FOR NULL VALUES

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE determinandlabel IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the codedResultInterpretationinterpretation column

# %%
### CHECK THE codedResultInterpretationinterpretation COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT codedResultInterpretationinterpretation 
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# This column will not be used in the load phase because it contains only nulls.
# Out:
#   codedResultInterpretationinterpretation
# 0                                    None

# %% [markdown]
# ##### Examine the determinandunitlabel column

# %%
### CHECK THE determinandunitlabel COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT determinandunitlabel
    FROM dw_water_quality;
    
        """

df = pd.read_sql_query(query, conn)
df

# 12 unique units.
# Out:
#    determinandunitlabel
# 0                   ntu
# 1              unitless
# 2               pres/nf
# 3                  text
# 4                 us/cm
# 5                   ftu
# 6                     %
# 7                 coded
# 8                  mg/l
# 9                   cel
# 10                 ug/l
# 11              phunits

# %%
### CHECK THE determinandunitlabel COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE determinandunitlabel IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %%
### EXAMINE THE determinandunitlabel COLUMN IN THE STAGING TABLE ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT determinandunitlabel, COUNT(determinandunitlabel) cnt
    FROM dw_water_quality
GROUP BY determinandunitlabel
ORDER BY cnt;

        """

df = pd.read_sql_query(query, conn)
df

# 5 out of 12 units appear in less than 50 records.
# Out:
#    determinandunitlabel   cnt
# 0              unitless     2
# 1                  text     2
# 2                   ntu    16
# 3                   ftu    31
# 4                 coded    45
# 5               pres/nf    56
# 6                 us/cm    82
# 7                   cel   116
# 8               phunits   134
# 9                     %   139
# 10                 ug/l   565
# 11                 mg/l  1160

# %%
### CHECK THE determinandunitlabel COLUMN FOR TOTAL OUTLIERS ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE determinandunitlabel = 'unitless'
        UNION
SELECT * FROM dw_water_quality
    WHERE determinandunitlabel = 'text'
        UNION
SELECT * FROM dw_water_quality
    WHERE determinandunitlabel = 'coded';
    
        """

df = pd.read_sql_query(query, conn)
df

# These 49 records are to be deleted because they seem not to be important considering 
# their corresponding values in the determinanddefinition column.
# Out:
#     ID1      ID                                                @id  \
# 0     1     1.0  http://environment.data.gov.uk/water-quality/d...
# 1     1     1.0  http://environment.data.gov.uk/water-quality/d...
# 2     1     1.0  http://environment.data.gov.uk/water-quality/d...
# 3     2    11.0  http://environment.data.gov.uk/water-quality/d...
# 4     4     4.0  http://environment.data.gov.uk/water-quality/d...
# 5     5   110.0  http://environment.data.gov.uk/water-quality/d...
# 6    10    10.0  http://environment.data.gov.uk/water-quality/d...
# 7    10    10.0  http://environment.data.gov.uk/water-quality/d...
# 8    10    82.0  http://environment.data.gov.uk/water-quality/d...
# 9    11    11.0  http://environment.data.gov.uk/water-quality/d...
# 10   15   141.0  http://environment.data.gov.uk/water-quality/d...
# 11   16    16.0  http://environment.data.gov.uk/water-quality/d...
# 12   17    17.0  http://environment.data.gov.uk/water-quality/d...
# 13   18    18.0  http://environment.data.gov.uk/water-quality/d...
# 14   18   118.0  http://environment.data.gov.uk/water-quality/d...
# 15   20   120.0  http://environment.data.gov.uk/water-quality/d...
# 16   21   121.0  http://environment.data.gov.uk/water-quality/d...
# 17   40    40.0  http://environment.data.gov.uk/water-quality/d...
# 18   45    45.0  http://environment.data.gov.uk/water-quality/d...
# 19   50    50.0  http://environment.data.gov.uk/water-quality/d...
# 20   55    55.0  http://environment.data.gov.uk/water-quality/d...
# 21   63   559.0  http://environment.data.gov.uk/water-quality/d...
# 22   65   641.0  http://environment.data.gov.uk/water-quality/d...
# 23   66   651.0  http://environment.data.gov.uk/water-quality/d...
# 24   67   661.0  http://environment.data.gov.uk/water-quality/d...
# 25   90   802.0  http://environment.data.gov.uk/water-quality/d...
# 26  100   793.0  http://environment.data.gov.uk/water-quality/d...
# 27  105  1041.0  http://environment.data.gov.uk/water-quality/d...
# 28  106  1051.0  http://environment.data.gov.uk/water-quality/d...
# 29  111  1101.0  http://environment.data.gov.uk/water-quality/d...
# 30  112  1075.0  http://environment.data.gov.uk/water-quality/d...
# 31  119  1181.0  http://environment.data.gov.uk/water-quality/d...
# 32  122  1211.0  http://environment.data.gov.uk/water-quality/d...
# 33  123  1194.0  http://environment.data.gov.uk/water-quality/d...
# 34  124   985.0  http://environment.data.gov.uk/water-quality/d...
# 35  127  1225.0  http://environment.data.gov.uk/water-quality/d...
# 36  128  1235.0  http://environment.data.gov.uk/water-quality/d...
# 37  130  1264.0  http://environment.data.gov.uk/water-quality/d...
# 38  134  1277.0  http://environment.data.gov.uk/water-quality/d...
# 39  136  1324.0  http://environment.data.gov.uk/water-quality/d...
# 40  139  1354.0  http://environment.data.gov.uk/water-quality/d...
# 41  141  1374.0  http://environment.data.gov.uk/water-quality/d...
# 42  142  1384.0  http://environment.data.gov.uk/water-quality/d...
# 43  146  1451.0  http://environment.data.gov.uk/water-quality/d...
# 44  148  1444.0  http://environment.data.gov.uk/water-quality/d...
# 45  149  1454.0  http://environment.data.gov.uk/water-quality/d...
# 46  149  1481.0  http://environment.data.gov.uk/water-quality/d...
# 47  241  2401.0  http://environment.data.gov.uk/water-quality/d...
# 48  246  2451.0  http://environment.data.gov.uk/water-quality/d...
#
#                                   samplesamplingPoint  \
# 0   http://environment.data.gov.uk/water-quality/i...
# 1   http://environment.data.gov.uk/water-quality/i...
# 2   http://environment.data.gov.uk/water-quality/i...
# 3   http://environment.data.gov.uk/water-quality/i...
# 4   http://environment.data.gov.uk/water-quality/i...
# 5   http://environment.data.gov.uk/water-quality/i...
# 6   http://environment.data.gov.uk/water-quality/i...
# 7   http://environment.data.gov.uk/water-quality/i...
# 8   http://environment.data.gov.uk/water-quality/i...
# 9   http://environment.data.gov.uk/water-quality/i...
# 10  http://environment.data.gov.uk/water-quality/i...
# 11  http://environment.data.gov.uk/water-quality/i...
# 12  http://environment.data.gov.uk/water-quality/i...
# 13  http://environment.data.gov.uk/water-quality/i...
# 14  http://environment.data.gov.uk/water-quality/i...
# 15  http://environment.data.gov.uk/water-quality/i...
# 16  http://environment.data.gov.uk/water-quality/i...
# 17  http://environment.data.gov.uk/water-quality/i...
# 18  http://environment.data.gov.uk/water-quality/i...
# 19  http://environment.data.gov.uk/water-quality/i...
# 20  http://environment.data.gov.uk/water-quality/i...
# 21  http://environment.data.gov.uk/water-quality/i...
# 22  http://environment.data.gov.uk/water-quality/i...
# 23  http://environment.data.gov.uk/water-quality/i...
# 24  http://environment.data.gov.uk/water-quality/i...
# 25  http://environment.data.gov.uk/water-quality/i...
# 26  http://environment.data.gov.uk/water-quality/i...
# 27  http://environment.data.gov.uk/water-quality/i...
# 28  http://environment.data.gov.uk/water-quality/i...
# 29  http://environment.data.gov.uk/water-quality/i...
# 30  http://environment.data.gov.uk/water-quality/i...
# 31  http://environment.data.gov.uk/water-quality/i...
# 32  http://environment.data.gov.uk/water-quality/i...
# 33  http://environment.data.gov.uk/water-quality/i...
# 34  http://environment.data.gov.uk/water-quality/i...
# 35  http://environment.data.gov.uk/water-quality/i...
# 36  http://environment.data.gov.uk/water-quality/i...
# 37  http://environment.data.gov.uk/water-quality/i...
# 38  http://environment.data.gov.uk/water-quality/i...
# 39  http://environment.data.gov.uk/water-quality/i...
# 40  http://environment.data.gov.uk/water-quality/i...
# 41  http://environment.data.gov.uk/water-quality/i...
# 42  http://environment.data.gov.uk/water-quality/i...
# 43  http://environment.data.gov.uk/water-quality/i...
# 44  http://environment.data.gov.uk/water-quality/i...
# 45  http://environment.data.gov.uk/water-quality/i...
# 46  http://environment.data.gov.uk/water-quality/i...
# 47  http://environment.data.gov.uk/water-quality/i...
# 48  http://environment.data.gov.uk/water-quality/i...
#
#    samplesamplingPointnotation                  samplesamplingPointlabel  \
# 0                    AN-011396        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 1                    AN-011396        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 2                    AN-011262           STEANE PARK THE MANOR HOUSE STW
# 3                     AN-01558               ROBIN HOOD PH BUFFLERS HOLT
# 4                    AN-011265                   BLACKPIT FARM STW STOWE
# 5                    AN-011489           RED HOUSE NURSING HOME SYRESHAM
# 6                    AN-011489           RED HOUSE NURSING HOME SYRESHAM
# 7                    AN-011396        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 8                    AN-011396        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 9                     AN-01558               ROBIN HOOD PH BUFFLERS HOLT
# 10                    AN-01558               ROBIN HOOD PH BUFFLERS HOLT
# 11                   AN-011396        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 12                   AN-011471                  BUCKINGHAM GARDEN CENTRE
# 13                   AN-011489           RED HOUSE NURSING HOME SYRESHAM
# 14                   AN-011489           RED HOUSE NURSING HOME SYRESHAM
# 15                   AN-011489           RED HOUSE NURSING HOME SYRESHAM
# 16                    AN-01558               ROBIN HOOD PH BUFFLERS HOLT
# 17                   AN-011624   APOLLO OFFICE UNITS RADCLIVE RD GAWCOTT
# 18                   AN-011638    AKELEY WOOD SENIOR SCHOOL, AKELEY WOOD
# 19                   AN-011638    AKELEY WOOD SENIOR SCHOOL, AKELEY WOOD
# 20                    AN-01558               ROBIN HOOD PH BUFFLERS HOLT
# 21                 NE-42600608       BATES COLLIERY (FORMER) SITE RUNOFF
# 22                   AN-123656           ELSTOW LANDFILL SITE NORTH WEST
# 23                   AN-123660     ELSTOW SOUTH CLAY PITS, ELSTOW, BEDS.
# 24                   AN-123678  CHEQUERS PH AMPTHIL RD HOUGHTON CONQUEST
# 25                 NE-43100023                             OTTERBURN STW
# 26                    AN-01M14             R.OUSE WATER STRATFORD RD.BR.
# 27                   AN-031487                CLUBHOUSE GT.LINFORD LAKES
# 28                    AN-03577            WHITTLEBURY HALL STW WEST PARK
# 29                 MD-36789260           NON-TIDAL TRENT - BERRYHILL SWS
# 30                   AN-021255       TUSMORE PARK HOLDINGS TUSMORE OXON.
# 31                 MD-36791290   NORTON LANE D/S HEAKLEY HALL FARM DISCH
# 32                 MD-36791290   NORTON LANE D/S HEAKLEY HALL FARM DISCH
# 33                 MD-03332190                     COLES COTTAGE STP, FE
# 34                   AN-021255       TUSMORE PARK HOLDINGS TUSMORE OXON.
# 35                 MD-06988570             WAYSIDE STP, RADFORD ROAD, FE
# 36                 MD-06996430              KNOWLE FIELDS PLOT C STP, FE
# 37                 MD-03341300                   PRESTON BROOK WINDCROSS
# 38                    AN-02400               ADDINGTON MANOR EST.STW O/F
# 39                 MD-03341300                   PRESTON BROOK WINDCROSS
# 40                 MD-03341300                   PRESTON BROOK WINDCROSS
# 41                 MD-03341300                   PRESTON BROOK WINDCROSS
# 42                 MD-03341300                   PRESTON BROOK WINDCROSS
# 43                 AN-TF416908                                  HOWDALES
# 44                 MD-03341300                   PRESTON BROOK WINDCROSS
# 45                 MD-03341300                   PRESTON BROOK WINDCROSS
# 46                 AN-TF416908                                  HOWDALES
# 47                 NE-43100100                   REDE AT COTTONSHOPEFOOT
# 48                 NE-43100100                   REDE AT COTTONSHOPEFOOT
#
#    samplesampleDateTime determinandlabel  \
# 0   2001-01-08T12:00:00     NO FLOW/SAMP
# 1   2005-01-10T10:55:00     NO FLOW/SAMP
# 2   2013-08-01T11:30:00      D Site Insp
# 3   2001-04-11T11:20:00     NO FLOW/SAMP
# 4   2013-07-30T12:55:00      D Site Insp
# 5   2011-02-08T13:49:00      D Site Insp
# 6   2010-02-17T13:50:00      D Site Insp
# 7   2013-06-15T10:06:00     NO FLOW/SAMP
# 8   2014-10-09T16:44:00     NO FLOW/SAMP
# 9   2010-07-20T09:50:00     Site Inspect
# 10  2007-08-30T13:40:00     NO FLOW/SAMP
# 11  2013-10-21T15:00:00     NO FLOW/SAMP
# 12  2013-07-11T14:45:00     Site Inspect
# 13  2013-08-01T13:00:00      D Site Insp
# 14  2011-02-08T13:48:00      D Site Insp
# 15  2011-03-03T12:15:00      D Site Insp
# 16  2011-07-20T14:33:00     Site Inspect
# 17  2013-07-29T12:25:00     NO FLOW/SAMP
# 18  2013-06-05T10:25:00     NO FLOW/SAMP
# 19  2013-09-11T10:47:00     NO FLOW/SAMP
# 20  2013-07-11T14:10:00     Site Inspect
# 21  2014-06-06T10:15:00     Site Inspect
# 22  2009-06-29T08:50:00     NO FLOW/SAMP
# 23  2009-01-28T09:15:00     NO FLOW/SAMP
# 24  2009-08-10T10:00:00     NO FLOW/SAMP
# 25  2014-05-22T10:50:00     NO FLOW/SAMP
# 26  2000-03-22T14:38:00     NO FLOW/SAMP
# 27  2008-12-04T10:00:00     NO FLOW/SAMP
# 28  2008-03-13T13:20:00     NO FLOW/SAMP
# 29  2008-06-12T09:40:00     WethPresTemp
# 30  2005-10-12T11:40:00     NO FLOW/SAMP
# 31  2008-06-13T11:00:00     WethPresPrec
# 32  2008-06-13T11:00:00     Weth-Visibty
# 33  2004-04-06T13:55:00     Weth-Visibty
# 34  2000-06-28T12:40:00     NO FLOW/SAMP
# 35  2005-05-20T11:45:00     Weth-Visibty
# 36  2005-07-12T14:15:00     Weth-Visibty
# 37  2004-04-06T11:44:00     WethPresPrec
# 38  2002-10-24T14:00:00     NO FLOW/SAMP
# 39  2004-06-24T12:25:00     WethPresPrec
# 40  2004-08-04T10:18:00     Weth-Visibty
# 41  2004-08-13T11:55:00     Weth-Visibty
# 42  2004-08-13T11:55:00     WethPresTemp
# 43  2007-08-16T12:30:00     GCMS Vol Scn
# 44  2004-11-24T11:20:00     Weth-Visibty
# 45  2004-12-09T10:55:00     WethPresTemp
# 46  2007-08-16T12:30:00     GCMS LL sVol
# 47  2015-03-17T12:11:00     ICP-MS Semiq
# 48  2015-06-17T10:09:00        MR Screen
#
#                                 determinanddefinition  determinandnotation  \
# 0                                  No flow /No sample               7668.0
# 1                                  No flow /No sample               7668.0
# 2         Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 3                                  No flow /No sample               7668.0
# 4         Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 5         Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 6         Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 7                                  No flow /No sample               7668.0
# 8                                  No flow /No sample               7668.0
# 9                   Site Inspection : Pass/Fail (1/0)               4883.0
# 10                                 No flow /No sample               7668.0
# 11                                 No flow /No sample               7668.0
# 12                  Site Inspection : Pass/Fail (1/0)               4883.0
# 13        Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 14        Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 15        Descriptive Site Inspection : Pass/Fail 1/0               7444.0
# 16                  Site Inspection : Pass/Fail (1/0)               4883.0
# 17                                 No flow /No sample               7668.0
# 18                                 No flow /No sample               7668.0
# 19                                 No flow /No sample               7668.0
# 20                  Site Inspection : Pass/Fail (1/0)               4883.0
# 21                  Site Inspection : Pass/Fail (1/0)               4883.0
# 22                                 No flow /No sample               7668.0
# 23                                 No flow /No sample               7668.0
# 24                                 No flow /No sample               7668.0
# 25                                 No flow /No sample               7668.0
# 26                                 No flow /No sample               7668.0
# 27                                 No flow /No sample               7668.0
# 28                                 No flow /No sample               7668.0
# 29                              Weather : Temperature               1181.0
# 30                                 No flow /No sample               7668.0
# 31                            Weather : Precipitation               1183.0
# 32                               Weather : Visibility               6528.0
# 33                               Weather : Visibility               6528.0
# 34                                 No flow /No sample               7668.0
# 35                               Weather : Visibility               6528.0
# 36                               Weather : Visibility               6528.0
# 37                            Weather : Precipitation               1183.0
# 38                                 No flow /No sample               7668.0
# 39                            Weather : Precipitation               1183.0
# 40                               Weather : Visibility               6528.0
# 41                               Weather : Visibility               6528.0
# 42                              Weather : Temperature               1181.0
# 43  GCMS Screen : Volatile Screen : Semi Quantitative               4084.0
# 44                               Weather : Visibility               6528.0
# 45                              Weather : Temperature               1181.0
# 46                   GCMS Scan : Semi-Volatile Screen               9247.0
# 47         ICP-MS : Metals screen : Semi-quantitative               3401.0
# 48  GCMS Screen : Target Based multi-residue scree...               4994.0
#
#    resultQualifiernotation  result codedResultInterpretationinterpretation  \
# 0                     None     1.0                                    None
# 1                     None     0.0                                    None
# 2                     None     1.0                                    None
# 3                     None     0.0                                    None
# 4                     None     1.0                                    None
# 5                     None     0.0                                    None
# 6                     None     1.0                                    None
# 7                     None     0.0                                    None
# 8                     None     0.0                                    None
# 9                     None     1.0                                    None
# 10                    None     0.0                                    None
# 11                    None     0.0                                    None
# 12                    None     1.0                                    None
# 13                    None     0.0                                    None
# 14                    None     0.0                                    None
# 15                    None     1.0                                    None
# 16                    None     1.0                                    None
# 17                    None     0.0                                    None
# 18                    None     0.0                                    None
# 19                    None     0.0                                    None
# 20                    None     0.0                                    None
# 21                    None     1.0                                    None
# 22                    None     0.0                                    None
# 23                    None     0.0                                    None
# 24                    None     0.0                                    None
# 25                    None     0.0                                    None
# 26                    None     3.0                                    None
# 27                    None     0.0                                    None
# 28                    None     3.0                                    None
# 29                    None     4.0                                    None
# 30                    None     0.0                                    None
# 31                    None     1.0                                    None
# 32                    None     2.0                                    None
# 33                    None     2.0                                    None
# 34                    None     0.0                                    None
# 35                    None     3.0                                    None
# 36                    None     3.0                                    None
# 37                    None     2.0                                    None
# 38                    None     0.0                                    None
# 39                    None     1.0                                    None
# 40                    None     4.0                                    None
# 41                    None     4.0                                    None
# 42                    None     4.0                                    None
# 43                    None     1.0                                    None
# 44                    None     4.0                                    None
# 45                    None     2.0                                    None
# 46                    None     1.0                                    None
# 47                    None     1.0                                    None
# 48                    None     1.0                                    None
#
#    determinandunitlabel        samplesampledMaterialTypelabel  \
# 0                 coded                 FINAL SEWAGE EFFLUENT
# 1                 coded                 FINAL SEWAGE EFFLUENT
# 2                 coded                 FINAL SEWAGE EFFLUENT
# 3                 coded                 FINAL SEWAGE EFFLUENT
# 4                 coded                 FINAL SEWAGE EFFLUENT
# 5                 coded                 FINAL SEWAGE EFFLUENT
# 6                 coded                 FINAL SEWAGE EFFLUENT
# 7                 coded                 FINAL SEWAGE EFFLUENT
# 8                 coded                 FINAL SEWAGE EFFLUENT
# 9                 coded                 FINAL SEWAGE EFFLUENT
# 10                coded                 FINAL SEWAGE EFFLUENT
# 11                coded                 FINAL SEWAGE EFFLUENT
# 12                coded                 FINAL SEWAGE EFFLUENT
# 13                coded                 FINAL SEWAGE EFFLUENT
# 14                coded                 FINAL SEWAGE EFFLUENT
# 15                coded                            ANY SEWAGE
# 16                coded                 FINAL SEWAGE EFFLUENT
# 17                coded                 FINAL SEWAGE EFFLUENT
# 18                coded                 FINAL SEWAGE EFFLUENT
# 19                coded                 FINAL SEWAGE EFFLUENT
# 20                coded                 FINAL SEWAGE EFFLUENT
# 21                coded                    ANY TRADE EFFLUENT
# 22                coded                    ANY TRADE EFFLUENT
# 23                coded                    ANY TRADE EFFLUENT
# 24                coded                    ANY TRADE EFFLUENT
# 25                coded                 FINAL SEWAGE EFFLUENT
# 26                coded         RIVER / RUNNING SURFACE WATER
# 27                coded                 FINAL SEWAGE EFFLUENT
# 28                coded                    ANY TRADE EFFLUENT
# 29                coded         RIVER / RUNNING SURFACE WATER
# 30                coded                 FINAL SEWAGE EFFLUENT
# 31                coded         RIVER / RUNNING SURFACE WATER
# 32                coded         RIVER / RUNNING SURFACE WATER
# 33                coded                 FINAL SEWAGE EFFLUENT
# 34                coded                 FINAL SEWAGE EFFLUENT
# 35                coded                 FINAL SEWAGE EFFLUENT
# 36                coded                 FINAL SEWAGE EFFLUENT
# 37                coded         RIVER / RUNNING SURFACE WATER
# 38                coded                 FINAL SEWAGE EFFLUENT
# 39                coded         RIVER / RUNNING SURFACE WATER
# 40                coded         RIVER / RUNNING SURFACE WATER
# 41                coded         RIVER / RUNNING SURFACE WATER
# 42                coded         RIVER / RUNNING SURFACE WATER
# 43             unitless  GROUNDWATER - PURGED/PUMPED/REFILLED
# 44                coded         RIVER / RUNNING SURFACE WATER
# 45                coded         RIVER / RUNNING SURFACE WATER
# 46                 text  GROUNDWATER - PURGED/PUMPED/REFILLED
# 47             unitless         RIVER / RUNNING SURFACE WATER
# 48                 text         RIVER / RUNNING SURFACE WATER
#
#     sampleisComplianceSample  \
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# 5                       True
# 6                       True
# 7                       True
# 8                       True
# 9                       True
# 10                      True
# 11                      True
# 12                      True
# 13                      True
# 14                      True
# 15                      True
# 16                      True
# 17                      True
# 18                      True
# 19                      True
# 20                      True
# 21                      True
# 22                      True
# 23                      True
# 24                      True
# 25                      True
# 26                     False
# 27                      True
# 28                      True
# 29                     False
# 30                      True
# 31                     False
# 32                     False
# 33                      True
# 34                      True
# 35                      True
# 36                      True
# 37                     False
# 38                      True
# 39                     False
# 40                     False
# 41                     False
# 42                     False
# 43                     False
# 44                     False
# 45                     False
# 46                     False
# 47                     False
# 48                     False
#
#                                    samplepurposelabel  \
# 0                           COMPLIANCE AUDIT (PERMIT)
# 1                           COMPLIANCE AUDIT (PERMIT)
# 2                           COMPLIANCE AUDIT (PERMIT)
# 3                           COMPLIANCE AUDIT (PERMIT)
# 4                           COMPLIANCE AUDIT (PERMIT)
# 5                           COMPLIANCE AUDIT (PERMIT)
# 6                           COMPLIANCE AUDIT (PERMIT)
# 7                           COMPLIANCE AUDIT (PERMIT)
# 8                           COMPLIANCE AUDIT (PERMIT)
# 9                           COMPLIANCE AUDIT (PERMIT)
# 10                          COMPLIANCE AUDIT (PERMIT)
# 11                          COMPLIANCE AUDIT (PERMIT)
# 12                          COMPLIANCE AUDIT (PERMIT)
# 13                          COMPLIANCE AUDIT (PERMIT)
# 14                          COMPLIANCE AUDIT (PERMIT)
# 15                          COMPLIANCE AUDIT (PERMIT)
# 16                          COMPLIANCE AUDIT (PERMIT)
# 17                          COMPLIANCE AUDIT (PERMIT)
# 18                          COMPLIANCE AUDIT (PERMIT)
# 19                          COMPLIANCE AUDIT (PERMIT)
# 20                          COMPLIANCE AUDIT (PERMIT)
# 21                          COMPLIANCE AUDIT (PERMIT)
# 22                          COMPLIANCE AUDIT (PERMIT)
# 23                          COMPLIANCE AUDIT (PERMIT)
# 24                          COMPLIANCE AUDIT (PERMIT)
# 25  WATER QUALITY OPERATOR SELF MONITORING COMPLIA...
# 26  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 27                          COMPLIANCE AUDIT (PERMIT)
# 28                          COMPLIANCE AUDIT (PERMIT)
# 29       MONITORING  (UK GOVT POLICY - NOT GQA OR RE)
# 30                          COMPLIANCE AUDIT (PERMIT)
# 31           PLANNED INVESTIGATION (LOCAL MONITORING)
# 32           PLANNED INVESTIGATION (LOCAL MONITORING)
# 33                          COMPLIANCE AUDIT (PERMIT)
# 34                          COMPLIANCE AUDIT (PERMIT)
# 35                          COMPLIANCE AUDIT (PERMIT)
# 36                          COMPLIANCE AUDIT (PERMIT)
# 37  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 38                          COMPLIANCE AUDIT (PERMIT)
# 39  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 40  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 41  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 42  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 43  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 44  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 45  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 46  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 47  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 48  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
#
#     samplesamplingPointeasting  samplesamplingPointnorthing
# 0                     467020.0                     233400.0
# 1                     467020.0                     233400.0
# 2                     455510.0                     239070.0
# 3                     466660.0                     235220.0
# 4                     467660.0                     239950.0
# 5                     462060.0                     240890.0
# 6                     462060.0                     240890.0
# 7                     467020.0                     233400.0
# 8                     467020.0                     233400.0
# 9                     466660.0                     235220.0
# 10                    466660.0                     235220.0
# 11                    467020.0                     233400.0
# 12                    467600.0                     233410.0
# 13                    462060.0                     240890.0
# 14                    462060.0                     240890.0
# 15                    462060.0                     240890.0
# 16                    466660.0                     235220.0
# 17                    467993.0                     232851.0
# 18                    468847.0                     237506.0
# 19                    468847.0                     237506.0
# 20                    466660.0                     235220.0
# 21                    430343.0                     582199.0
# 22                    504203.0                     246300.0
# 23                    505070.0                     245400.0
# 24                    503066.0                     240255.0
# 25                    389130.0                     592620.0
# 26                    465205.0                     234067.0
# 27                    484910.0                     242770.0
# 28                    468740.0                     242380.0
# 29                    389000.0                     346450.0
# 30                    456690.0                     230220.0
# 31                    390100.0                     351300.0
# 32                    390100.0                     351300.0
# 33                    367930.0                     230660.0
# 34                    456690.0                     230220.0
# 35                    400840.0                     254511.0
# 36                    404154.0                     257993.0
# 37                    369200.0                     232490.0
# 38                    474300.0                     228700.0
# 39                    369200.0                     232490.0
# 40                    369200.0                     232490.0
# 41                    369200.0                     232490.0
# 42                    369200.0                     232490.0
# 43                    541592.0                     390878.0
# 44                    369200.0                     232490.0
# 45                    369200.0                     232490.0
# 46                    541592.0                     390878.0
# 47                    377820.0                     601280.0
# 48                    377820.0                     601280.0

# %%
### CHECK THE determinanddefinition COLUMN INFO OF determinandunitlabel COLUMN ENTRIES THAT LOOKS ODD ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT s.determinanddefinition FROM
    (
    SELECT * FROM dw_water_quality
        WHERE determinandunitlabel = 'unitless'
            UNION
    SELECT * FROM dw_water_quality
        WHERE determinandunitlabel = 'text'	
            UNION
    SELECT * FROM dw_water_quality
        WHERE determinandunitlabel = 'coded'
    ) s;
    
        """

df = pd.read_sql_query(query, conn)
df

# The result summary below shows the reason why these 49 records seem not to be important.
# Out:
#                                determinanddefinition
# 0        Descriptive Site Inspection : Pass/Fail 1/0
# 1                   GCMS Scan : Semi-Volatile Screen
# 2  GCMS Screen : Target Based multi-residue scree...
# 3  GCMS Screen : Volatile Screen : Semi Quantitative
# 4         ICP-MS : Metals screen : Semi-quantitative
# 5                                 No flow /No sample
# 6                  Site Inspection : Pass/Fail (1/0)
# 7                            Weather : Precipitation
# 8                              Weather : Temperature
# 9                               Weather : Visibility

# %% [markdown]
# ##### Examine the sampleisComplianceSample  column

# %%
### CHECK THE sampleisComplianceSample COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT sampleisComplianceSample
    FROM dw_water_quality;
        
        """

df = pd.read_sql_query(query, conn)
df

# 2 unique results (1 and 0. This implies "compliant" and "non-compliant" respectively).
# Out:
#    sampleisComplianceSample
# 0                     False
# 1                      True

# %%
### CHECK THE sampleisComplianceSample COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE sampleisComplianceSample IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesampledMaterialTypelabel column

# %%
### CHECK THE samplesampledMaterialTypelabel COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesampledMaterialTypelabel 
    FROM dw_water_quality;
        
        """

df = pd.read_sql_query(query, conn)
df

# 9 unique values.
# Out:
#                     samplesampledMaterialTypelabel
# 0                               ANY TRADE EFFLUENT
# 1             GROUNDWATER - PURGED/PUMPED/REFILLED
# 2  RUNNING SURFACE WATER SEDIMENT - <63UM FRACTION
# 3                            FINAL SEWAGE EFFLUENT
# 4                                          UNCODED
# 5                                      GROUNDWATER
# 6                                       ANY SEWAGE
# 7                                        ANY WATER
# 8                    RIVER / RUNNING SURFACE WATER

# %%
### CHECK THE samplesampledMaterialTypelabel COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesampledMaterialTypelabel IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplepurposelabel column

# %%
### CHECK THE samplepurposelabel COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplepurposelabel 
    FROM dw_water_quality;
        
        """

df = pd.read_sql_query(query, conn)
df

# 14 unique values.
# Out:
#                                    samplepurposelabel
# 0   UNPLANNED REACTIVE MONITORING FORMAL (POLLUTIO...
# 1      PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2            PLANNED INVESTIGATION (LOCAL MONITORING)
# 3        MONITORING  (UK GOVT POLICY - NOT GQA OR RE)
# 4   ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 5   UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
# 6                           COMPLIANCE AUDIT (PERMIT)
# 7                 WATER QUALITY UWWTD MONITORING DATA
# 8            ENVIRONMENTAL MONITORING (GQA & RE ONLY)
# 9   WATER QUALITY OPERATOR SELF MONITORING COMPLIA...
# 10               MONITORING  (NATIONAL AGENCY POLICY)
# 11                         COMPLIANCE FORMAL (PERMIT)
# 12  STATUTORY FAILURES (FOLLOW UPS AT NON-DESIGNAT...
# 13                   UNSPECIFIED AT TIME OF WIMS LOAD

# %%
### CHECK THE samplepurposelabel COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplepurposelabel IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesamplingPointeasting column

# %%
### CHECK THE samplesamplingPointeasting COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesamplingPointeasting 
    FROM dw_water_quality;
        
        """

df = pd.read_sql_query(query, conn)
df

# 80 unique values!!
# Out:
#     samplesamplingPointeasting
# 0                     475760.0
# 1                     465800.0
# 2                     479484.0
# 3                     471467.0
# 4                     450491.0
# ..                         ...
# 75                    478766.0
# 76                    466660.0
# 77                    494702.0
# 78                    492020.0
# 79                    458404.0
#
# [80 rows x 1 columns]

# %%
### CHECK THE samplesamplingPointeasting COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesamplingPointeasting IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Examine the samplesamplingPointnorthing column

# %%
### CHECK THE samplesamplingPointnorthing COLUMN FOR DISTINCT VALUES ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT DISTINCT samplesamplingPointnorthing 
    FROM dw_water_quality;
        
        """

df = pd.read_sql_query(query, conn)
df

# 81 unique results.
# Out:
#     samplesamplingPointnorthing
# 0                      232851.0
# 1                      237506.0
# 2                      228850.0
# 3                      592620.0
# 4                      230220.0
# ..                          ...
# 76                     238550.0
# 77                     250870.0
# 78                     240255.0
# 79                     228700.0
# 80                     249257.0
#
# [81 rows x 1 columns]

# %%
### CHECK THE samplesamplingPointnorthing COLUMN FOR NULL VALUES ###

## You can run this cell more than once. Expect an empty dataframe ##

query = """

SELECT * FROM dw_water_quality
    WHERE samplesamplingPointnorthing IS NULL;
    
        """

df = pd.read_sql_query(query, conn)
df

# No null records.
# Out:
# Empty DataFrame
# Columns: [ID1, ID, @id, samplesamplingPoint, samplesamplingPointnotation, samplesamplingPointlabel, samplesampleDateTime, determinandlabel, determinanddefinition, determinandnotation, resultQualifiernotation, result, codedResultInterpretationinterpretation, determinandunitlabel, samplesampledMaterialTypelabel, sampleisComplianceSample, samplepurposelabel, samplesamplingPointeasting, samplesamplingPointnorthing]
# Index: []

# %% [markdown]
# ##### Data cleaning...

# %%
### DATA CLEANING 1: TO REMOVE UNNECESSARY RECORDS ###

## Deleting is done using the distinct column "@id" as a unique key column!

## Run this cell only once. Expect no output ##

cursor.execute("""

DELETE FROM dw_water_quality 
    WHERE [@id] IN
        (
        SELECT s.[@id] FROM
            (
            SELECT * FROM dw_water_quality
                WHERE determinandunitlabel = 'unitless'
                    UNION
            SELECT * FROM dw_water_quality
                WHERE determinandunitlabel = 'text'	
                    UNION
            SELECT * FROM dw_water_quality
                WHERE determinandunitlabel = 'coded'
            ) s
        );
        
            """)

conn.commit()

# %%
### DATA CLEANING 2: TO REMOVE REDUNDANT PARTS OF ENTRIES ###

## To strip off all appearances of “http://environment.data.gov.uk/water-quality” from the @id and samplesamplingpoint columns

## Run this cell only once. Expect no output ##

cursor.execute("""

UPDATE dw_water_quality
    SET [@id] = REPLACE([@id], 'http://environment.data.gov.uk/water-quality', '');

            """)

conn.commit()



cursor.execute("""

UPDATE dw_water_quality
    SET samplesamplingpoint = REPLACE(samplesamplingpoint, 'http://environment.data.gov.uk/water-quality', '');
    
            """)

conn.commit()

# %%
### EXAMINE THE RESIDUAL STAGING TABLE SO FAR ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dw_water_quality;

        """

df = pd.read_sql_query(query, conn)
df

# 49 out of 2348 records were deleted. 2299 records remaining.
# Out:
#       ID1      ID                                @id  \
# 0       1     1.0   /data/measurement/AN-687353-0111
# 1       2     9.0  /data/measurement/AN-1053332-0135
# 2       3    17.0  /data/measurement/AN-1037010-0135
# 3       4    25.0   /data/measurement/AN-689676-6051
# 4       5    33.0   /data/measurement/AN-689676-0135
# ...   ...     ...                                ...
# 2294  255  1352.0  /data/measurement/AN-1673460-0135
# 2295  255  2541.0  /data/measurement/NE-1542543-0239
# 2296  256  1353.0  /data/measurement/AN-1676129-0135
# 2297  257  1354.0  /data/measurement/AN-1676129-0117
# 2298  258  1355.0  /data/measurement/AN-1676129-0118
#
#                  samplesamplingPoint samplesamplingPointnotation  \
# 0       /id/sampling-point/AN-011396                   AN-011396
# 1       /id/sampling-point/AN-011396                   AN-011396
# 2       /id/sampling-point/AN-011489                   AN-011489
# 3        /id/sampling-point/AN-01M04                    AN-01M04
# 4        /id/sampling-point/AN-01M04                    AN-01M04
# ...                              ...                         ...
# 2294     /id/sampling-point/AN-02M10                    AN-02M10
# 2295  /id/sampling-point/NE-43100100                 NE-43100100
# 2296     /id/sampling-point/AN-02M10                    AN-02M10
# 2297     /id/sampling-point/AN-02M10                    AN-02M10
# 2298     /id/sampling-point/AN-02M10                    AN-02M10
#
#                    samplesamplingPointlabel samplesampleDateTime  \
# 0        BUCKINGHAM GOLF CLUB TINGEWICK RD.  2000-01-04T14:10:00
# 1        BUCKINGHAM GOLF CLUB TINGEWICK RD.  2000-11-15T14:50:00
# 2           RED HOUSE NURSING HOME SYRESHAM  2000-07-17T10:15:00
# 3                R.OUSE A422 RD.BR.BRACKLEY  2000-01-24T10:55:00
# 4                R.OUSE A422 RD.BR.BRACKLEY  2000-01-24T10:55:00
# ...                                     ...                  ...
# 2294  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD  2012-05-21T11:31:00
# 2295                REDE AT COTTONSHOPEFOOT  2015-11-30T10:59:00
# 2296  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD  2012-06-14T14:29:00
# 2297  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD  2012-06-14T14:29:00
# 2298  PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD  2012-06-14T14:29:00
#
#      determinandlabel       determinanddefinition  determinandnotation  \
# 0          Ammonia(N)    Ammoniacal Nitrogen as N                111.0
# 1        Sld Sus@105C  Solids, Suspended at 105 C                135.0
# 2        Sld Sus@105C  Solids, Suspended at 105 C                135.0
# 3        Iron - as Fe                        Iron               6051.0
# 4        Sld Sus@105C  Solids, Suspended at 105 C                135.0
# ...               ...                         ...                  ...
# 2294     Sld Sus@105C  Solids, Suspended at 105 C                135.0
# 2295      Ca Filtered          Calcium, Dissolved                239.0
# 2296     Sld Sus@105C  Solids, Suspended at 105 C                135.0
# 2297        Nitrate-N                Nitrate as N                117.0
# 2298        Nitrite-N                Nitrite as N                118.0
#
#      resultQualifiernotation    result  \
# 0                       None   10.4000
# 1                       None   14.4000
# 2                       None   65.3000
# 3                       None  160.0000
# 4                       None    4.0000
# ...                      ...       ...
# 2294                    None    3.7800
# 2295                    None   10.2000
# 2296                    None    8.6700
# 2297                    None    6.0400
# 2298                    None    0.0378
#
#      codedResultInterpretationinterpretation determinandunitlabel  \
# 0                                       None                 mg/l
# 1                                       None                 mg/l
# 2                                       None                 mg/l
# 3                                       None                 ug/l
# 4                                       None                 mg/l
# ...                                      ...                  ...
# 2294                                    None                 mg/l
# 2295                                    None                 mg/l
# 2296                                    None                 mg/l
# 2297                                    None                 mg/l
# 2298                                    None                 mg/l
#
#      samplesampledMaterialTypelabel  sampleisComplianceSample  \
# 0             FINAL SEWAGE EFFLUENT                      True
# 1             FINAL SEWAGE EFFLUENT                      True
# 2             FINAL SEWAGE EFFLUENT                     False
# 3     RIVER / RUNNING SURFACE WATER                     False
# 4     RIVER / RUNNING SURFACE WATER                     False
# ...                             ...                       ...
# 2294  RIVER / RUNNING SURFACE WATER                     False
# 2295  RIVER / RUNNING SURFACE WATER                     False
# 2296  RIVER / RUNNING SURFACE WATER                     False
# 2297  RIVER / RUNNING SURFACE WATER                     False
# 2298  RIVER / RUNNING SURFACE WATER                     False
#
#                                      samplepurposelabel  \
# 0                             COMPLIANCE AUDIT (PERMIT)
# 1                             COMPLIANCE AUDIT (PERMIT)
# 2     UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
# 3     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4     ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# ...                                                 ...
# 2294     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2295  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 2296     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2297     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 2298     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
#
#       samplesamplingPointeasting  samplesamplingPointnorthing
# 0                       467020.0                     233400.0
# 1                       467020.0                     233400.0
# 2                       462060.0                     240890.0
# 3                       459427.0                     236819.0
# 4                       459427.0                     236819.0
# ...                          ...                          ...
# 2294                    470377.0                     228850.0
# 2295                    377820.0                     601280.0
# 2296                    470377.0                     228850.0
# 2297                    470377.0                     228850.0
# 2298                    470377.0                     228850.0
#
# [2299 rows x 19 columns]

# %% [markdown]
# ##### At this point, column selection, BUS plan, as well as fact and dimension tables design should be done.

# %% [markdown]
# ### Load Phase

# %%
### TO CREATE DIMENSION TABLES AND FACT TABLE AND LOAD THEM ###

## Run this cell only once. Expect no output ##


cursor.execute("""

--- To rename the 15 columns ---

EXEC sp_rename 'dw_water_quality.[@id]', 'measurementMetadata', 'COLUMN';
    
EXEC sp_rename 'dw_water_quality.samplesamplingPoint', 'locationMetadata', 'COLUMN';
    
EXEC sp_rename 'dw_water_quality.samplesamplingPointnotation', 'locationNotation', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplesamplingPointlabel', 'measurementLocation', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplesampleDateTime', 'measurementDateTime', 'COLUMN';

EXEC sp_rename 'dw_water_quality.determinandlabel', 'sensorType', 'COLUMN';

EXEC sp_rename 'dw_water_quality.determinanddefinition', 'sensorTypeDefinition', 'COLUMN';
    
EXEC sp_rename 'dw_water_quality.determinandnotation', 'sensorNotation', 'COLUMN';

EXEC sp_rename 'dw_water_quality.result', 'measurement', 'COLUMN';

EXEC sp_rename 'dw_water_quality.determinandunitlabel', 'sensorUnit', 'COLUMN';
    
EXEC sp_rename 'dw_water_quality.sampleisComplianceSample', 'sampleCompliance', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplesampledMaterialTypelabel', 'samplingMaterial', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplepurposelabel', 'samplingPurpose', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplesamplingPointeasting', 'locationEasting', 'COLUMN';

EXEC sp_rename 'dw_water_quality.samplesamplingPointnorthing', 'locationNorthing', 'COLUMN';



--- To typecast the measurementDateTime column into DATETIME datatype ---

ALTER TABLE dw_water_quality ALTER COLUMN measurementDateTime DATETIME;


--- To add a measurementYear column of INTEGER datatype ---

ALTER TABLE dw_water_quality ADD measurementYear INT;

            """)

conn.commit()



cursor.execute("""

--- To populate the measurementYear column with year data from measurementDateTime column ---

UPDATE dw_water_quality SET measurementYear = YEAR(measurementDateTime) WHERE measurementMetadata = measurementMetadata;

--- or, UPDATE dw_water_quality SET measurementYear = DATENAME(year, measurementDateTime) WHERE measurementMetadata = measurementMetadata;


--- To add a measurementWeek column of INTEGER datatype ---

ALTER TABLE dw_water_quality ADD measurementWeek INT;

            """)

conn.commit()



cursor.execute("""

--- To populate the measurementWeek column with week data from measurementDateTime column ---

UPDATE dw_water_quality SET measurementWeek = DATEPART(WEEK, measurementDateTime) WHERE measurementMetadata = measurementMetadata;


--- To add a measurementMonth column of NVARCHAR datatype ---

ALTER TABLE dw_water_quality ADD measurementMonth NVARCHAR(15);

            """)

conn.commit()



cursor.execute("""

--- To populate the measurementMonth column with week data from measurementDateTime column ---

UPDATE dw_water_quality SET measurementMonth = DATENAME(MONTH, measurementDateTime) WHERE measurementMetadata = measurementMetadata;

            """)

conn.commit()



cursor.execute("""

--- To create 9 dimension tables and a fact table ---

CREATE TABLE dimLocationTable (
    locationID INT NOT NULL PRIMARY KEY IDENTITY,
    locationMetadata NVARCHAR(255) NOT NULL,
    locationNotation NVARCHAR(255) NOT NULL,
    measurementLocation NVARCHAR(255) NOT NULL,
    locationEasting INT NOT NULL,
    locationNorthing INT NOT NULL
    );

CREATE TABLE dimPurposeTable (
    purposeID INT NOT NULL PRIMARY KEY IDENTITY,
    samplingPurpose NVARCHAR(255) NOT NULL
    );
    
CREATE TABLE dimComplianceTable (
    complianceID INT NOT NULL PRIMARY KEY IDENTITY,
    sampleCompliance INT NOT NULL
    );
    
CREATE TABLE dimSampleTable (
    sampleID INT NOT NULL PRIMARY KEY IDENTITY,
    samplingMaterial NVARCHAR(255) NOT NULL,
    );    
    
CREATE TABLE dimSensorTable (
    sensorID INT NOT NULL PRIMARY KEY IDENTITY,
    sensorType NVARCHAR(255) NOT NULL,
    sensorTypeDefinition NVARCHAR(255) NOT NULL,
    sensorNotation INT NOT NULL,
    sensorUnit NVARCHAR(255) NOT NULL
    );

CREATE TABLE dimYearTable (
    yearID INT NOT NULL PRIMARY KEY IDENTITY,
    measurementYear INT NOT NULL
    );

CREATE TABLE dimWeekTable (
    weekID INT NOT NULL PRIMARY KEY IDENTITY,
    measurementWeek INT NOT NULL
    );

CREATE TABLE dimMonthTable (
    monthID INT NOT NULL PRIMARY KEY IDENTITY,
    measurementMonth NVARCHAR(15) NOT NULL
    );

CREATE TABLE dimTimeTable (
    dateTimeID INT NOT NULL PRIMARY KEY IDENTITY,
    measurementDateTime DATETIME NOT NULL,
    yearID INT NOT NULL FOREIGN KEY REFERENCES dimYearTable(yearID),
    weekID INT NOT NULL FOREIGN KEY REFERENCES dimWeekTable(weekID),
    monthID INT NOT NULL FOREIGN KEY REFERENCES dimMonthTable(monthID)
    );

CREATE TABLE factMeasurementsTable (
    factID INT NOT NULL PRIMARY KEY IDENTITY,
    locationID INT NOT NULL FOREIGN KEY REFERENCES dimLocationTable(locationID),
    dateTimeID INT NOT NULL FOREIGN KEY REFERENCES dimTimeTable(dateTimeID),
    sensorID INT NOT NULL FOREIGN KEY REFERENCES dimSensorTable(sensorID),
    purposeID INT NOT NULL FOREIGN KEY REFERENCES dimPurposeTable(purposeID),
    complianceID INT NOT NULL FOREIGN KEY REFERENCES dimComplianceTable(complianceID),
    sampleID INT NOT NULL FOREIGN KEY REFERENCES dimSampleTable(sampleID),
    measurement FLOAT NOT NULL,
    sensorUnit NVARCHAR(255) NOT NULL
    );
  
            """)

conn.commit()



cursor.execute("""

--- To add reference ID columns with INTEGER datatype to the staging table from the 9 dimension tables ---

ALTER TABLE dw_water_quality ADD locationID INT;

ALTER TABLE dw_water_quality ADD dateTimeID INT;

ALTER TABLE dw_water_quality ADD sensorID INT;

ALTER TABLE dw_water_quality ADD yearID INT;

ALTER TABLE dw_water_quality ADD monthID INT;

ALTER TABLE dw_water_quality ADD weekID INT;

ALTER TABLE dw_water_quality ADD purposeID INT;

ALTER TABLE dw_water_quality ADD complianceID INT;

ALTER TABLE dw_water_quality ADD sampleID INT;

            """)

conn.commit()



cursor.execute("""

--- To load each of the 9 dimension tables with data as well as update the staging table with their IDs ---

INSERT INTO dimLocationTable(locationMetadata, locationNotation, measurementLocation, locationEasting, locationNorthing)
    SELECT DISTINCT locationMetadata, locationNotation, measurementLocation, locationEasting, locationNorthing
        FROM dw_water_quality 
    ORDER BY locationMetadata;

UPDATE dw_water_quality 
    SET dw_water_quality.locationID = dimLocationTable.locationID 
        FROM dw_water_quality 
    INNER JOIN dimLocationTable 
        ON dw_water_quality.measurementLocation = dimLocationTable.measurementLocation;

INSERT INTO dimSensorTable(sensorType, sensorTypeDefinition, sensorNotation, sensorUnit)
    SELECT DISTINCT sensorType, sensorTypeDefinition, sensorNotation, sensorUnit
        FROM dw_water_quality 
    ORDER BY sensorType;

UPDATE dw_water_quality 
    SET dw_water_quality.sensorID = dimSensorTable.sensorID 
        FROM dw_water_quality 
    INNER JOIN dimSensorTable 
        ON dw_water_quality.sensorType = dimSensorTable.sensorType;

INSERT INTO dimYearTable(measurementYear)
    SELECT DISTINCT measurementYear 
        FROM dw_water_quality 
    ORDER BY measurementYear;

UPDATE dw_water_quality 
    SET dw_water_quality.yearID = dimYearTable.yearID 
        FROM dw_water_quality 
    INNER JOIN dimYearTable 
        ON dw_water_quality.measurementYear = dimYearTable.measurementYear;

INSERT INTO dimWeekTable(measurementWeek)
    SELECT DISTINCT measurementWeek 
        FROM dw_water_quality 
    ORDER BY measurementWeek;

UPDATE dw_water_quality 
    SET dw_water_quality.weekID = dimWeekTable.weekID 
        FROM dw_water_quality 
    INNER JOIN dimWeekTable 
        ON dw_water_quality.measurementWeek = dimWeekTable.measurementWeek;

INSERT INTO dimMonthTable(measurementMonth)
    SELECT s.measurementMonth FROM 
        (
        SELECT DISTINCT measurementMonth, DATEPART(MONTH, measurementDateTime) c 
            FROM dw_water_quality
        ) s 
    ORDER BY c ASC;

UPDATE dw_water_quality 
    SET dw_water_quality.monthID = dimMonthTable.monthID 
        FROM dw_water_quality 
    INNER JOIN dimMonthTable 
        ON dw_water_quality.measurementMonth = dimMonthTable.measurementMonth;

INSERT INTO dimTimeTable(measurementDateTime, yearID, weekID, monthID)
    SELECT DISTINCT measurementDateTime, yearID, weekID, monthID 
        FROM dw_water_quality 
    ORDER BY yearID ASC;

UPDATE dw_water_quality 
    SET dw_water_quality.dateTimeID = dimTimeTable.dateTimeID 
        FROM dw_water_quality 
    INNER JOIN dimTimeTable 
        ON dw_water_quality.measurementDateTime = dimTimeTable.measurementDateTime
    AND dw_water_quality.yearID = dimTimeTable.yearID
    AND dw_water_quality.monthID = dimTimeTable.monthID
    AND dw_water_quality.weekID = dimTimeTable.weekID;
    
INSERT INTO dimPurposeTable(samplingPurpose)
    SELECT DISTINCT samplingPurpose 
        FROM dw_water_quality 
    ORDER BY samplingPurpose;

UPDATE dw_water_quality
    SET dw_water_quality.purposeID = dimPurposeTable.purposeID 
        FROM dw_water_quality 
    INNER JOIN dimPurposeTable 
        ON dw_water_quality.samplingPurpose = dimPurposeTable.samplingPurpose;
        
INSERT INTO dimComplianceTable(sampleCompliance)
    SELECT DISTINCT sampleCompliance 
        FROM dw_water_quality 
    ORDER BY sampleCompliance;

UPDATE dw_water_quality
    SET dw_water_quality.complianceID = dimComplianceTable.complianceID 
        FROM dw_water_quality 
    INNER JOIN dimComplianceTable 
        ON dw_water_quality.sampleCompliance = dimComplianceTable.sampleCompliance;
        
INSERT INTO dimSampleTable(samplingMaterial)
    SELECT DISTINCT samplingMaterial 
        FROM dw_water_quality 
    ORDER BY samplingMaterial;

UPDATE dw_water_quality
    SET dw_water_quality.sampleID = dimSampleTable.sampleID 
        FROM dw_water_quality 
    INNER JOIN dimSampleTable 
        ON dw_water_quality.samplingMaterial = dimSampleTable.samplingMaterial;
        
INSERT INTO factMeasurementsTable (
    locationID, dateTimeID, sensorID, purposeID, complianceID, sampleID, measurement, sensorUnit
    ) 
    SELECT 
        l.locationID, t.dateTimeID, s.sensorID, p.purposeID, c.complianceID, sm.sampleID, wq.measurement, s.sensorUnit
    FROM dw_water_quality wq
        INNER JOIN dimLocationTable l 
    ON wq.measurementLocation = l.measurementLocation
        INNER JOIN dimSensorTable s 
    ON wq.sensorType = s.sensorType
        INNER JOIN dimPurposeTable p 
    ON wq.samplingPurpose = p.samplingPurpose
        INNER JOIN dimComplianceTable c 
    ON wq.sampleCompliance = c.sampleCompliance
        INNER JOIN dimSampleTable sm 
    ON wq.samplingMaterial = sm.samplingMaterial
        INNER JOIN dimTimeTable t 
    ON wq.measurementDateTime = t.measurementDateTime
        INNER JOIN dimYearTable y 
    ON wq.measurementYear = y.measurementYear
        INNER JOIN dimWeekTable w 
    ON wq.measurementWeek = w.measurementWeek
        INNER JOIN dimMonthTable m 
    ON wq.measurementMonth = m.measurementMonth;

            """)

conn.commit()

# %% [markdown]
# ###### At this point the ER (entity relationship) diagram or schema diagram should be ready to view in SQL Server Management Studio.

# %% [markdown]
# ##### The journey so far: The 9 dimension tables (including the Extended Time table), and the fact table

# %%
### THE factMeasurementsTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM factMeasurementsTable;

        """

df = pd.read_sql_query(query, conn)
df

# 2299 ENTRIES
# Out:
#       factID  locationID  dateTimeID  sensorID  purposeID  complianceID  \
# 0          1           3           1        24          1             2
# 1          2           3          52       144          1             2
# 2          3           4          34       144         10             1
# 3          4          10           6        88          4             1
# 4          5          10           6       144          4             1
# ...      ...         ...         ...       ...        ...           ...
# 2294    2295          26         668       144          8             1
# 2295    2296          69         949        43          4             1
# 2296    2297          26         670       144          8             1
# 2297    2298          26         670       111          8             1
# 2298    2299          26         670       112          8             1
#
#       sampleID  measurement sensorUnit
# 0            4      10.4000       mg/l
# 1            4      14.4000       mg/l
# 2            4      65.3000       mg/l
# 3            7     160.0000       ug/l
# 4            7       4.0000       mg/l
# ...        ...          ...        ...
# 2294         7       3.7800       mg/l
# 2295         7      10.2000       mg/l
# 2296         7       8.6700       mg/l
# 2297         7       6.0400       mg/l
# 2298         7       0.0378       mg/l
#
# [2299 rows x 9 columns]

# %%
### THE dimLocationTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimLocationTable;

        """

df = pd.read_sql_query(query, conn)
df

# 72 ENTRIES
# Out:
#     locationID                locationMetadata locationNotation  \
# 0            1    /id/sampling-point/AN-011262        AN-011262
# 1            2    /id/sampling-point/AN-011265        AN-011265
# 2            3    /id/sampling-point/AN-011396        AN-011396
# 3            4    /id/sampling-point/AN-011489        AN-011489
# 4            5    /id/sampling-point/AN-011553        AN-011553
# ..         ...                             ...              ...
# 67          68  /id/sampling-point/NE-43100098      NE-43100098
# 68          69  /id/sampling-point/NE-43100100      NE-43100100
# 69          70  /id/sampling-point/NE-45401467      NE-45401467
# 70          71  /id/sampling-point/NE-45401488      NE-45401488
# 71          72  /id/sampling-point/NE-454F1115      NE-454F1115
#
#                        measurementLocation  locationEasting  locationNorthing
# 0          STEANE PARK THE MANOR HOUSE STW           455510            239070
# 1                  BLACKPIT FARM STW STOWE           467660            239950
# 2       BUCKINGHAM GOLF CLUB TINGEWICK RD.           467020            233400
# 3          RED HOUSE NURSING HOME SYRESHAM           462060            240890
# 4   BP CONNECT, BRACKLEY, NORTHAMPTONSHIRE           459250            238550
# ..                                     ...              ...               ...
# 67                  CHIRDON BURN AT TARSET           378320            585035
# 68                 REDE AT COTTONSHOPEFOOT           377820            601280
# 69  BISHOPTON BECK D/S MILL BR PUMPING STN           437930            522500
# 70    MARTON WEST BECK BELOW LYTTON STREET           450491            519949
# 71            ELSTOB HILL (NRA 15) 25-4-35           434900            523000
#
# [72 rows x 6 columns]

# %%
### THE dimSensorTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimSensorTable;

        """

df = pd.read_sql_query(query, conn)
df

# 163 ENTRIES
# Out:
#      sensorID    sensorType        sensorTypeDefinition  sensorNotation  \
# 0           1     1,1,1-TCA       1,1,1-Trichloroethane            3268
# 1           2     1,2,4-TCB      1,2,4-Trichlorobenzene            9051
# 2           3  1122TetClEth   1,1,2,2-Tetrachloroethane            7531
# 3           4        12-DCA          1,2-Dichloroethane            3272
# 4           5  2,3,5,6-Tetr  2,3,5,6-Tetrachloroaniline            9350
# ..        ...           ...                         ...             ...
# 158       159     Turbidity                   Turbidity              68
# 159       160  TurbidityNTU                   Turbidity            6396
# 160       161   Uranium - U                     Uranium            6473
# 161       162  Zinc - as Zn                        Zinc            6455
# 162       163  Zn- Filtered             Zinc, Dissolved            3408
#
#     sensorUnit
# 0         ug/l
# 1         ug/l
# 2         ug/l
# 3         ug/l
# 4         ug/l
# ..         ...
# 158        ftu
# 159        ntu
# 160       ug/l
# 161       ug/l
# 162       ug/l
#
# [163 rows x 5 columns]

# %%
### THE dimPurposeTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimPurposeTable;

        """

df = pd.read_sql_query(query, conn)
df

# 14 ENTRIES
# Out:
#     purposeID                                    samplingPurpose
# 0           1                          COMPLIANCE AUDIT (PERMIT)
# 1           2                         COMPLIANCE FORMAL (PERMIT)
# 2           3           ENVIRONMENTAL MONITORING (GQA & RE ONLY)
# 3           4  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4           5               MONITORING  (NATIONAL AGENCY POLICY)
# 5           6       MONITORING  (UK GOVT POLICY - NOT GQA OR RE)
# 6           7           PLANNED INVESTIGATION (LOCAL MONITORING)
# 7           8     PLANNED INVESTIGATION (NATIONAL AGENCY POLICY)
# 8           9  STATUTORY FAILURES (FOLLOW UPS AT NON-DESIGNAT...
# 9          10  UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
# 10         11  UNPLANNED REACTIVE MONITORING FORMAL (POLLUTIO...
# 11         12                   UNSPECIFIED AT TIME OF WIMS LOAD
# 12         13  WATER QUALITY OPERATOR SELF MONITORING COMPLIA...
# 13         14                WATER QUALITY UWWTD MONITORING DATA

# %%
### THE dimComplianceTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimComplianceTable;

        """

df = pd.read_sql_query(query, conn)
df

# 2 ENTRIES
# Out:
#    complianceID  sampleCompliance
# 0             1                 0
# 1             2                 1

# %%
### THE dimSampleTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimSampleTable;

        """

df = pd.read_sql_query(query, conn)
df

# 9 ENTRIES
# Out:
#    sampleID                                 samplingMaterial
# 0         1                                       ANY SEWAGE
# 1         2                               ANY TRADE EFFLUENT
# 2         3                                        ANY WATER
# 3         4                            FINAL SEWAGE EFFLUENT
# 4         5                                      GROUNDWATER
# 5         6             GROUNDWATER - PURGED/PUMPED/REFILLED
# 6         7                    RIVER / RUNNING SURFACE WATER
# 7         8  RUNNING SURFACE WATER SEDIMENT - <63UM FRACTION
# 8         9                                          UNCODED

# %%
### THE dimTimeTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimTimeTable;

        """

df = pd.read_sql_query(query, conn)
df

# 1049 ENTRIES
# Out:
#       dateTimeID measurementDateTime  yearID  weekID  monthID
# 0              1 2000-01-04 14:10:00       1       2        1
# 1              2 2000-01-10 13:25:00       1       3        1
# 2              3 2000-01-24 09:40:00       1       5        1
# 3              4 2000-01-24 10:00:00       1       5        1
# 4              5 2000-01-24 10:25:00       1       5        1
# ...          ...                 ...     ...     ...      ...
# 1044        1045 2016-12-05 13:58:00      17      50       12
# 1045        1046 2016-12-05 14:23:00      17      50       12
# 1046        1047 2016-12-05 15:05:00      17      50       12
# 1047        1048 2016-12-07 13:00:00      17      50       12
# 1048        1049 2016-12-16 10:32:00      17      51       12
#
# [1049 rows x 5 columns]

# %%
### THE dimYearTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimYearTable;

        """

df = pd.read_sql_query(query, conn)
df

# 17 ENTRIES
# Out:
#     yearID  measurementYear
# 0        1             2000
# 1        2             2001
# 2        3             2002
# 3        4             2003
# 4        5             2004
# 5        6             2005
# 6        7             2006
# 7        8             2007
# 8        9             2008
# 9       10             2009
# 10      11             2010
# 11      12             2011
# 12      13             2012
# 13      14             2013
# 14      15             2014
# 15      16             2015
# 16      17             2016

# %%
### THE dimWeekTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimWeekTable;

        """

df = pd.read_sql_query(query, conn)
df

# 52 ENTRIES
# Out:
#     weekID  measurementWeek
# 0        1                1
# 1        2                2
# 2        3                3
# 3        4                4
# 4        5                5
# 5        6                6
# 6        7                7
# 7        8                8
# 8        9                9
# 9       10               10
# 10      11               11
# 11      12               12
# 12      13               13
# 13      14               14
# 14      15               15
# 15      16               16
# 16      17               17
# 17      18               18
# 18      19               19
# 19      20               20
# 20      21               21
# 21      22               22
# 22      23               23
# 23      24               24
# 24      25               25
# 25      26               26
# 26      27               27
# 27      28               28
# 28      29               29
# 29      30               30
# 30      31               31
# 31      32               32
# 32      33               33
# 33      34               34
# 34      35               35
# 35      36               36
# 36      37               37
# 37      38               38
# 38      39               39
# 39      40               40
# 40      41               41
# 41      42               42
# 42      43               43
# 43      44               44
# 44      45               45
# 45      46               46
# 46      47               47
# 47      48               48
# 48      49               49
# 49      50               50
# 50      51               51
# 51      52               53

# %%
### THE dimMonthTable ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT * FROM dimMonthTable;

        """

df = pd.read_sql_query(query, conn)
df

# 12 ENTRIES
# Out:
#     monthID measurementMonth
# 0         1          January
# 1         2         February
# 2         3            March
# 3         4            April
# 4         5              May
# 5         6             June
# 6         7             July
# 7         8           August
# 8         9        September
# 9        10          October
# 10       11         November
# 11       12         December

# %% [markdown]
# ### Querying our Data Warehouse Implementation To Get Information

# %%
### The list of water sensors measured by type by month ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT 
    s.measurementMonth, s.sensorType, s.numberOfSensors FROM
    (
    SELECT 
        mt.measurementMonth, 
        st.sensorType, 
        COUNT(measurement) numberOfSensors
    FROM 
        dimSensorTable st 
        INNER JOIN factMeasurementsTable fm ON st.sensorID = fm.sensorID
        INNER JOIN dimTimeTable tt ON fm.dateTimeID = tt.dateTimeID
        INNER JOIN dimMonthTable mt ON tt.monthID = mt.monthID
    GROUP BY 
        st.sensorType, mt.measurementMonth 
    ) s 
JOIN dimMonthTable mt ON s.measurementMonth = mt.measurementMonth
ORDER BY 
    mt.monthID, s.sensorType;
    
        """

df = pd.read_sql_query(query, conn)
df

# 634 rows returned.
# Out:
#     measurementMonth    sensorType  numberOfSensors
# 0            January       2,4,6-T                1
# 1            January   2,6-Xylenol                1
# 2            January   3,4 Xylenol                1
# 3            January   Alky pH 4.5                4
# 4            January    Ammonia(N)               20
# ..               ...           ...              ...
# 629         December   Sodium - Na                1
# 630         December    Temp Water               10
# 631         December     Turbidity                4
# 632         December  TurbidityNTU                2
# 633         December  Zinc - as Zn                3
#
# [634 rows x 3 columns]

# %%
### The number of sensor measurements collected by type by week ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT 
    wt.measurementWeek, 
    st.sensorType, 
    COUNT(measurement) numberOfMeasurements
FROM 
    dimSensorTable st 
    INNER JOIN factMeasurementsTable fm ON st.sensorID = fm.sensorID
    INNER JOIN dimTimeTable tt ON fm.dateTimeID = tt.dateTimeID
    INNER JOIN dimWeekTable wt ON tt.weekID = wt.weekID
GROUP BY 
    st.sensorType, wt.measurementWeek
ORDER BY
    wt.measurementWeek, st.sensorType;
    
        """

df = pd.read_sql_query(query, conn)
df

# 1258 rows returned.
# Out:
#       measurementWeek    sensorType  numberOfMeasurements
# 0                   1   Metaldehyde                     1
# 1                   1  Sld Sus@105C                     1
# 2                   2   Alky pH 4.5                     1
# 3                   2    Ammonia(N)                     8
# 4                   2  Cadmium - Cd                     1
# ...               ...           ...                   ...
# 1253               51            pH                     1
# 1254               51  Phosphorus-P                     1
# 1255               51     Turbidity                     2
# 1256               51  Zinc - as Zn                     1
# 1257               53  Phenol Odour                     1
#
# [1258 rows x 3 columns]

# %%
### The number of measurements made by location by month ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT 
    s.measurementMonth, s.measurementLocation, s.numberOfMeasurements FROM
    (
    SELECT 
        mt.measurementMonth, 
        lt.measurementLocation, 
        COUNT(measurement) numberOfMeasurements
    FROM 
        dimLocationTable lt 
        INNER JOIN factMeasurementsTable fm ON lt.locationID = fm.locationID
        INNER JOIN dimTimeTable tt ON fm.dateTimeID = tt.dateTimeID
        INNER JOIN dimMonthTable mt ON tt.monthID = mt.monthID
    GROUP BY 
        lt.measurementLocation, mt.measurementMonth
    ) s
JOIN dimMonthTable mt ON s.measurementMonth = mt.measurementMonth
ORDER BY 
    mt.monthID, s.measurementLocation;
    
        """

df = pd.read_sql_query(query, conn)
df

# 399 rows returned.
# Out:
#     measurementMonth                       measurementLocation  \
# 0            January   APOLLO OFFICE UNITS RADCLIVE RD GAWCOTT
# 1            January    BISHOPTON BECK D/S MILL BR PUMPING STN
# 2            January     BLAKESLEY BK.TRIB.TOVE KINGTHORN MILL
# 3            January        BUCKINGHAM GOLF CLUB TINGEWICK RD.
# 4            January              CASWELL BK.TRIB.TOVE CASWELL
# ..               ...                                       ...
# 394         December                 SULGRAVE BK.WESTON RD.BR.
# 395         December  SYRESHAM STR.TRIB.OUSE.A43 RD.BR.KINDSHL
# 396         December        TRIB.CLIPSTONE BK.RD.BR.MANOR FARM
# 397         December               TRIB.OUZEL BK.D/S BLUEWATER
# 398         December           WILLOUGHTON BROOK AT BLYBOROUGH
#
#      numberOfMeasurements
# 0                       4
# 1                       1
# 2                       2
# 3                       9
# 4                       3
# ..                    ...
# 394                     1
# 395                    15
# 396                     1
# 397                     1
# 398                     2
#
# [399 rows x 3 columns]

# %%
### The average number of measurements covered for pH by year ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT 
    yt.measurementYear, 
    COUNT(measurement) numberOfMeasurements
FROM 
    dimSensorTable st 
    INNER JOIN factMeasurementsTable fm ON st.sensorID = fm.sensorID
    INNER JOIN dimTimeTable tt ON fm.dateTimeID = tt.dateTimeID
    INNER JOIN dimYearTable yt ON tt.yearID = yt.yearID
WHERE 
    st.sensorType = 'pH'
GROUP BY 
    yt.measurementYear
ORDER BY 
    yt.measurementYear;
    
        """

df = pd.read_sql_query(query, conn)
df

# 16 rows returned. It is immediately observed that there were no pH measurements recorded for the year 2013.
# Out:
#     measurementYear  numberOfMeasurements
# 0              2000                     5
# 1              2001                     6
# 2              2002                     6
# 3              2003                    11
# 4              2004                     6
# 5              2005                     9
# 6              2006                     4
# 7              2007                     4
# 8              2008                    11
# 9              2009                     6
# 10             2010                     8
# 11             2011                     6
# 12             2012                    19
# 13             2014                    10
# 14             2015                    15
# 15             2016                     8

# %%
### The average value of nitrate measurements by locations by year ###

## You can run this cell more than once. Expect a dataframe ##

query = """

SELECT 
    yt.measurementYear,
    lt.measurementLocation,
    ROUND(AVG(measurement), 2) averageValuesOfNitrate
FROM 
    dimLocationTable lt 
    INNER JOIN factMeasurementsTable fm ON lt.locationID = fm.locationID
    INNER JOIN dimSensorTable st ON fm.sensorID = st.sensorID
    INNER JOIN dimTimeTable tt ON fm.dateTimeID = tt.dateTimeID
    INNER JOIN dimYearTable yt ON tt.yearID = yt.yearID
WHERE 
    st.sensorType = 'Nitrate-N'
GROUP BY 
    lt.measurementLocation, yt.measurementYear
ORDER BY 
    yt.measurementYear, lt.measurementLocation;
    
        """

df = pd.read_sql_query(query, conn)
df

# 42 rows returned. It also observed that there were no Nitrate measurements recorded for the years 2001, 2002, and 2013.
# Out:
#     measurementYear                       measurementLocation  \
# 0              2000                R.OUSE A422 RD.BR.BRACKLEY
# 1              2003                R.OUSE A422 RD.BR.BRACKLEY
# 2              2003                       R.OUSE BOURTON MILL
# 3              2004                   PRESTON BROOK WINDCROSS
# 4              2004                       R.OUSE BOURTON MILL
# 5              2004             R.OUSE WATER STRATFORD RD.BR.
# 6              2005                R.OUSE A422 RD.BR.BRACKLEY
# 7              2006                R.OUSE A422 RD.BR.BRACKLEY
# 8              2006                       R.OUSE BOURTON MILL
# 9              2007                R.OUSE A422 RD.BR.BRACKLEY
# 10             2007                       R.OUSE BOURTON MILL
# 11             2008                R.OUSE A422 RD.BR.BRACKLEY
# 12             2008             R.OUSE WATER STRATFORD RD.BR.
# 13             2009                       R.OUSE BOURTON MILL
# 14             2009             R.OUSE WATER STRATFORD RD.BR.
# 15             2010                R.OUSE A422 RD.BR.BRACKLEY
# 16             2010  SYRESHAM STR.TRIB.OUSE.A43 RD.BR.KINDSHL
# 17             2011  SYRESHAM STR.TRIB.OUSE.A43 RD.BR.KINDSHL
# 18             2012     PADBURY BK.TRIB.OUSE KINGSBRIDGE FORD
# 19             2012       PADBURY BK.TRIB.OUSE PRESTON BISSET
# 20             2012  PADBURY BK.TRIB.OUSE STRATTON AUDLEY MIL
# 21             2014    BISHOPTON BECK D/S MILL BR PUMPING STN
# 22             2014                          BUTTERYHAUGH STW
# 23             2014           DUDDO BURN AT WHINNEY HILL FARM
# 24             2014      MARTON WEST BECK BELOW LYTTON STREET
# 25             2014                             OTTERBURN STW
# 26             2014                       R.OUSE BOURTON MILL
# 27             2014             R.OUSE WATER STRATFORD RD.BR.
# 28             2015                    CHIRDON BURN AT TARSET
# 29             2015   HINTON STR.TRIB.OUSE A43 RD.BR.BRACKLEY
# 30             2015                              LEAPLISH STW
# 31             2015                R.OUSE A422 RD.BR.BRACKLEY
# 32             2015                       R.OUSE BOURTON MILL
# 33             2015             R.OUSE WATER STRATFORD RD.BR.
# 34             2015  RADSTONE BK.TRIB.OUSE A43 RD.BR.WHITFIEL
# 35             2015      STOWE BK. TRIB. OUSE WELSH LANE FORD
# 36             2015  SYRESHAM STR.TRIB.OUSE.A43 RD.BR.KINDSHL
# 37             2015                     TARSET BURN AT TARSET
# 38             2015        TRIB.CLIPSTONE BK.RD.BR.MANOR FARM
# 39             2016                    R.TOVE ABTHORPE RD.BR.
# 40             2016               R.TOVE COSGROVE PARK FT.BR.
# 41             2016                 SILVERSTONE BK.A43 RD.BR.
#
#     averageValuesOfNitrate
# 0                     6.45
# 1                     7.82
# 2                    14.30
# 3                     5.68
# 4                     9.76
# 5                    12.80
# 6                     6.61
# 7                     5.52
# 8                    12.29
# 9                     6.83
# 10                    8.93
# 11                    6.04
# 12                    8.05
# 13                    6.73
# 14                    9.85
# 15                    7.41
# 16                    6.65
# 17                    5.65
# 18                    8.19
# 19                    1.43
# 20                   11.10
# 21                    5.09
# 22                   17.80
# 23                    2.59
# 24                    3.79
# 25                   17.00
# 26                    6.91
# 27                    9.29
# 28                    0.20
# 29                    4.18
# 30                    4.00
# 31                    2.67
# 32                    6.68
# 33                    3.50
# 34                    6.23
# 35                    2.70
# 36                    4.31
# 37                    0.20
# 38                    5.43
# 39                   11.50
# 40                    7.29
# 41                    9.33

# %%
### Endeavour to run this cell in order to close the connection to the database.

conn.close()

# %% [markdown]
# ##### End of demonstration. Thank you for staying with me on this!
